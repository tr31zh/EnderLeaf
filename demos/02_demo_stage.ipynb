# %% [markdown]
# ## Enderscopy stage demo

# %% [markdown]
# ### This notebook shows how to connect and drive an enderscope stage from Python.

# %%
# Needed to import from the enderscope library

import os

os.chdir("..")

# %%
import time
from enderscope.serial import SerialUtils, Stage

# %%
# list available serial ports
ports = SerialUtils.serial_ports()
print (ports)
# Out:
# ['/dev/tty.Bluetooth-Incoming-Port', '/dev/tty.usbmodem144201']

# %%
stageport = ports[1]

# %%
# connect to enderscope and create a stage object
s = Stage(stageport, 115200)

# %%
# home the stage for positionning reproducibility
s.home()
s.get_position()
# Out:
# (0.0, 0.0, 0.0)

# %%
# move to (x,y(,z)) absolute coordinate
s.move_absolute(0,0,10)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/anaconda3/envs/enderscope/lib/python3.9/site-packages/serial/serialposix.py:621, in Serial.write(self, data)
#     620 try:
# --> 621     n = os.write(self.fd, d)
#     622     if timeout.is_non_blocking:
#     623         # Zero timeout indicates non-blocking - simply return the
#     624         # number of bytes of data actually written
#
# OSError: [Errno 6] Device not configured
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# Cell In[14], line 2
#       1 # move to (x,y(,z)) absolute coordinate
# ----> 2 s.move_absolute(0,0,10)
#
# File ~/Documents/GitHub/enderscopy/enderscope.py:114, in Stage.move_absolute(self, x, y, z, debug)
#     106 def move_absolute(self, x, y, z=None, debug=False):
#     107     """
#     108     Moves the stage to the given coordinates
#     109     :param x:
#    (...)
#     112     :return:
#     113     """
# --> 114     self.set_absolute()
#     115     if z is None:
#     116         code = f"G0 X {x} Y {y}"
#
# File ~/Documents/GitHub/enderscopy/enderscope.py:205, in Stage.set_absolute(self, debug)
#     204 def set_absolute(self, debug=False):
# --> 205     self.write_code(G_CODES['absolute'], debug=debug)
#
# File ~/Documents/GitHub/enderscopy/enderscope.py:95, in Stage.write_code(self, code, check_ok, debug)
#      94 def write_code(self, code, check_ok=True, debug=False):
# ---> 95     super().write_code(code)
#      96     response = self.serial.readline().decode('utf-8')
#      97     if check_ok:
#
# File ~/Documents/GitHub/enderscopy/enderscope.py:81, in SerialDevice.write_code(self, code)
#      79 if not code.endswith("\n"):
#      80     code += "\n"
# ---> 81 self.serial.write(bytes(code, "utf-8"))
#
# File ~/anaconda3/envs/enderscope/lib/python3.9/site-packages/serial/serialposix.py:655, in Serial.write(self, data)
#     650 except OSError as e:
#     651     # this is for Python 3.x where select.error is a subclass of
#     652     # OSError ignore BlockingIOErrors and EINTR. other errors are shown
#     653     # https://www.python.org/dev/peps/pep-0475.
#     654     if e.errno not in (errno.EAGAIN, errno.EALREADY, errno.EWOULDBLOCK, errno.EINPROGRESS, errno.EINTR):
# --> 655         raise SerialException('write failed: {}'.format(e))
#     656 except select.error as e:
#     657     # this is for Python 2.x
#     658     # ignore BlockingIOErrors and EINTR. all errors are shown
#     659     # see also http://www.python.org/dev/peps/pep-3151/#select
#     660     if e[0] not in (errno.EAGAIN, errno.EALREADY, errno.EWOULDBLOCK, errno.EINPROGRESS, errno.EINTR):
#
# SerialException: write failed: [Errno 6] Device not configured

# %%
# move (x,y(,z)) mm distances relative to start position
s.move_relative(10,0)
s.move_relative(-10,0)

# %%
# move relative along single axis 
s.move_axis('y',10)

# %%
# iterate over list of positions
# positions can be lists or tuples of length 2 or 3
positions = [[0,0,0],[0,10],(10,10,10),[10,0]]
for i in range(5):
    for pos in positions:
        s.move_position(pos)
        s.finish_moves() 
s.get_position()
# Out:
# (10.0, 0.0, 10.0)

# %%
# you can head towards standard directions, distances are always > 0
s.move_towards('east',30)
s.move_towards('north',30)
s.move_towards('west',30)
s.move_towards('south',30)

# %%
# GCode commands are sent in a queue to printer
for i in range(15):
    s.move_relative(1,0,0)

# use finish_moves to wait for printer to settle between moves
for i in range(15):
    s.move_relative(-1,0,0)
    s.finish_moves()

# %% [markdown]
# ### > see advanced stage notebook for more options
