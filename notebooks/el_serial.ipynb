# %%
# Needed to import from the enderscope library

import os

os.chdir("..")

# %%
from enderscope import serial as es

# %%
for port in es.list_ports():
    print(port)
# Out:
# /dev/ttyUSB0 - USB Serial
# /dev/ttyAMA0 - n/a
# /dev/ttyAMA10 - n/a

# %%
port = es.list_ports()[0]

# %%
port.description
# Out:
# 'USB Serial'

# %%
port.device
# Out:
# '/dev/ttyUSB0'

# %%
port.manufacturer

# %%
port.product
# Out:
# 'USB Serial'

# %%
port.usb_description
# Out:
# <bound method ListPortInfo.usb_description of <serial.tools.list_ports_linux.SysFS object at 0x7fff306a9230>>
