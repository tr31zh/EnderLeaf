# %%
import serial

# %%
import serial.tools.list_ports

# %%
for port in serial.tools.list_ports.comports():
    print(port)
# Out:
# /dev/cu.BLTH - n/a
# /dev/cu.JabraElite75t - n/a
# /dev/cu.Bluetooth-Incoming-Port - n/a

# %%
from serial.tools.list_ports import comports

for port in comports():

    print(port)
# Out:
# /dev/cu.BLTH - n/a
# /dev/cu.JabraElite75t - n/a
# /dev/cu.Bluetooth-Incoming-Port - n/a

# %%
comports()
# Out:
# [<serial.tools.list_ports_common.ListPortInfo at 0x10bb80d10>,
#  <serial.tools.list_ports_common.ListPortInfo at 0x10bb80e20>,
#  <serial.tools.list_ports_common.ListPortInfo at 0x10b765250>]

# %%
port.description
# Out:
# 'n/a'

# %%
port.device
# Out:
# '/dev/cu.Bluetooth-Incoming-Port'

# %%
port.manufacturer

# %%
port
