# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Needed to import from the enderscope library

import os

os.chdir("..")

# %%
import time
import math
from enderscope.enderlights_pi import Enderlights, cycle

# %%
lights = Enderlights()
lights

# %%
lights.shutter(False)

# %%
for i in cycle(lights, 3, 3, (255, 0, 255)):
    print(i)
    time.sleep(0.5)
lights.shutter(False)

# %%
lights[0] = (255, 0, 0)
lights[1] = (0, 255, 0)
lights[2] = (0, 0, 255)

# %%
lights.shutter(False)
lights.red(127)
time.sleep(2)
lights.green(127)
time.sleep(2)
lights.blue(127)
time.sleep(2)
lights.shutter(False)
