# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
# Needed to import from the enderscope library

import os

os.chdir("..")

# %% [markdown]
# # Imports

# %%
from enderleaf.enderleaf_mini import main, sidebar
from enderleaf.enderleaf_ui import controller
from enderscope.enderlights_pi import LIGHTS_CYCLE

import panel as pn

# %% [markdown]
# ## Display

# %%
# controller.acq_light_configurations = [
#     LIGHTS_CYCLE[2],
#     LIGHTS_CYCLE[3],
#     LIGHTS_CYCLE[4],
#     LIGHTS_CYCLE[5],
# ]

pn.Row(sidebar, main)
