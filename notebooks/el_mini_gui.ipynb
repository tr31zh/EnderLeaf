# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
# Needed to import from the enderscope library

import os

os.chdir("..")

# %% [markdown]
# # Imports

# %%
import asyncio

from enderleaf.image import to_pil
from enderleaf.enderleaf_ctrl import EnderLeafController

# %% [markdown]
# ## Controller

# %%
controller = EnderLeafController()

# %%
await controller.start()

# %%
controller.top_lights.pixels

# %%
img, metad = await controller.capture_array()
to_pil(img)

# %%
await controller.stop()
